# %%
import pandas as pd 
df = pd.read_csv("Arabic tweets classification project/clean_data.csv")
df=df.dropna()
df.reset_index(inplace=True)
df.head()
# Out:
#    index                   id  \
# 0      0  1175358310087892992
# 1      1  1175416117793349632
# 2      2  1175450108898565888
# 3      3  1175471073770573824
# 4      4  1175496913145217024
#
#                                                  txt dialect
# 0                                بالنهاية ينتفض يغير      IQ
# 1  يعني محسوب البشر حيونه ووحشيه وتطلبون الغرب يح...      IQ
# 2                                   مبين كلامه خليجي      IQ
# 3                          يسلملي مرورك وروحك الحلوه      IQ
# 4                                 وين الغيبه اخ محمد      IQ

# %%
X = df['txt']
y = df['dialect']
df
# Out:
#          index                   id  \
# 0            0  1175358310087892992
# 1            1  1175416117793349632
# 2            2  1175450108898565888
# 3            3  1175471073770573824
# 4            4  1175496913145217024
# ...        ...                  ...
# 457768  457995  1088352896842956800
# 457769  457996  1088437262499659776
# 457770  457997  1088665169616687232
# 457771  457998  1090527423844806784
# 457772  457999  1090947679977439232
#
#                                                       txt dialect
# 0                                     بالنهاية ينتفض يغير      IQ
# 1       يعني محسوب البشر حيونه ووحشيه وتطلبون الغرب يح...      IQ
# 2                                        مبين كلامه خليجي      IQ
# 3                               يسلملي مرورك وروحك الحلوه      IQ
# 4                                      وين الغيبه اخ محمد      IQ
# ...                                                   ...     ...
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
x_train =list(x_train)
x_train
# Out:
# ['انت عم تحمل مسولية لفة معينةلو بتاكل خرا شو بكون منيح شو بكون احسنلان الكل مسول حدا مظلوممش بس ضدك السبب بتحبو خصوو طول نحنا هيك رح نضل محلنا منرجع لورا اكتر اكتر واكتر',
#  'عقباال عبدالقادر الشهراني شا الله الدرع مايتعدي رجال شهران بعون الله كلنا معكم ابوحور وعبدالقادرزدرصيدك',
#  'الحقيقة انا اننا نقيد حرية حد يفطر يصوم علشان مجرد يرضينا احناومش عارفة اقتنع اني اكون صايمة يبقي حقي اتضايق حد يفطر قدامي صايمة وانا مقتنعة وممنة باهمية الصوم مش حيفرق معايا مين صايم ومين فاطر لان دي حاجة بيني ربنا',
#  'يمكنها طايحه مخش بس مضن مخك ماركه عشان تتساقط نعل ماركه حد مخك نعال طايحه الاطلال يعني مصديه ومحليه',
#  'الامومة الجد بحسها تستلمني بعوضة وادعي ربنا تاكلني بس ماتقرب ايليا نوح',
#  'الكل يعرف الناس نهايتهم الموت ليش نخاف اللي نحبهم انهم يموتون',
#  'عقبال الدكاتره اللي بتجار بالشعب',
#  'تراني اقولك تقول لون سيارة المطافي تخيل العباه سودا والجوتي بالللون كيلو بتشوفه',
#  'اللي يصير بالسياره',
# ...

# %%
y_train
# Out:
# 311605    LB
# 213479    SA
# 283748    EG
# 61039     QA
# 89846     PL
#           ..
# 141661    SY
# 417364    AE
# 62603     QA
# 276161    EG
# 12954     IQ
# Name: dialect, Length: 366218, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline


vec = TfidfVectorizer(analyzer='word', max_df=.5)
clf=LinearSVC(random_state=0, tol=1e-5)

model= Pipeline([('vctorizer',TfidfVectorizer(analyzer='word', max_df=.5)) , ('classifier',LinearSVC(random_state=0, tol=1e-5))])
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('vctorizer', TfidfVectorizer(max_df=0.5)),
#                 ('classifier', LinearSVC(random_state=0, tol=1e-05))])

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
ac = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy is :",ac)
print(report)
# Out:
# Accuracy is : 0.5195019387253563
#               precision    recall  f1-score   support
#
#           AE       0.39      0.40      0.40      5148
#           BH       0.36      0.31      0.33      5282
#           DZ       0.60      0.52      0.56      3302
#           EG       0.67      0.84      0.75     11499
#           IQ       0.60      0.50      0.55      3173
#           JO       0.39      0.33      0.36      5502
#           KW       0.46      0.54      0.50      8473
#           LB       0.61      0.65      0.63      5587
#           LY       0.64      0.67      0.66      7341
#           MA       0.73      0.60      0.66      2337
#           OM       0.39      0.31      0.34      3813
#           PL       0.47      0.53      0.50      8766
#           QA       0.44      0.47      0.46      6036
#           SA       0.39      0.38      0.38      5416
#           SD       0.67      0.55      0.61      2848
#           SY       0.43      0.30      0.36      3201
# ...

# %%
import pickle
pkl_filename = 'Arabic tweets classification project/model.pkl'
with open(pkl_filename, 'wb') as f:
    pickle.dump(model, f)
